# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load trained model
model = YOLO(r"F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\runs\detect\train\weights\best.pt")

# Run inference on a test image
results = model(r"F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\test\images", show=True, save=True, conf=0.4)

# Show results using OpenCV
img = cv2.imread("F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\runs\detect\predict")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# image 1/153 F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\test\images\101307074_544e234e97_jpg.rf.4df7388a4a5a7910b56f6312c48801c4.jpg: 640x640 2 Shoes, 72.1ms
# image 2/153 F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\test\images\117kallis_jpg.rf.2e789e3c0292b47d315df6ada2040bd9.jpg: 640x640 (no detections), 86.8ms
# image 3/153 F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\test\images\2NvJBz6L-1k7CGGgdo6m-wLBPYCUMYIHRJxJ_ACkIE_PoYpb4MTniNnSoik6_jpeg_jpg.rf.46b7de7377d2b0e06bbc4f6696d689d3.jpg: 640x640 1 Shoe, 87.8ms
# image 4/153 F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\test\images\3ec8jsZa3UNR4Gp9olHDBqA9HGMnkfxmqMthVcHgYo-HHT20KwdffS4lJBUR_jpeg_jpg.rf.b8ff1ac50a7b41d0c0fc2969902e6586.jpg: 640x640 1 Shoe, 88.3ms
# image 5/153 F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\test\images\4_jpg.rf.e47be73a82c870ba179755f061260873.jpg: 640x640 (no detections), 87.3ms
# ...

# %%
#test video data
from ultralytics import YOLO

# Load trained YOLOv8 model
model = YOLO("runs/detect/train/weights/best.pt")

# Run inference on a video file
results = model.predict(source="F:\malathi\AI\DEEP_LEARNING\Shoe_detect_2\shoe_video.mp4", save=True, conf=0.4)

print("✅ Prediction complete! Check the saved output in 'runs/detect/predict'")
